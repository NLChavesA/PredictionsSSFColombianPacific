# %% [markdown]
# <a href="https://colab.research.google.com/github/NLChavesA/PredictionsSSFColombianPacific/blob/main/SSF_DPAnalysis_Video.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Analysis of the artisanal fishing or Small-Scale Fisheries (SSF) function in the colombian pacific
# ##Video
# ![Inicial.png](data:image/png;base64,...) [link text](https://youtu.be/XyD_aHbaz4E)

# %% [markdown]
# #Contents
#
# 1. General problem addressed.
# 1. Data analytics problem addressed.
# 2. A description of the data used to address the problem.
# 3. A brief description of the main findings of the IDA exercise.
